# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %% [markdown]
# !mongoimport --type json -d uk_foods -c establishments--drop --jsonArray .\Resources\establishments.json

# %%
# !mongoimport --type json -d uk_foods -c establishments --jsonArray --drop .\Resources\establishments.json
# Out:
# 2024-02-01T20:44:09.374-0500	connected to: mongodb://localhost/
# 2024-02-01T20:44:09.375-0500	dropping: uk_foods.establishments
# 2024-02-01T20:44:11.458-0500	39779 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin',
#  'autosaurus',
#  'classDB',
#  'config',
#  'fruits_db',
#  'local',
#  'met',
#  'petsitly_marketing',
#  'travel_db',
#  'uk_foods']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_foods']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments--drop', 'establishments']

# %%
# review a document in the establishments collection
pprint(db['establishments'].find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48e966d5369e5b7e6e08'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
establishments.find_one()
# Out:
# {'_id': ObjectId('65bc48e966d5369e5b7e6e08'),
#  'FHRSID': 254719,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT15 6DY',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2022-03-24T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#  'RightToReply': '',
#  'Distance': 4587.347174863443,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]}

# %% [markdown]
# ## Part 3: Exploratory Analysis
#
# Unless otherwise stated, for each question:
#
# Use count_documents to display the number of documents contained in the result.
# Display the first document in the results using pprint.
# Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# # 1. Which establishments have a hygiene score equal to 20?

# %%
#Find the establishments with a hygiene score of 20
query = {'scores.Hygiene' :20}
results = establishments.find(query)
pprint(results[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48e966d5369e5b7e8c33'),
#  'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Use count_documents to display the number of documents in the result
number_of_doc = establishments.count_documents({'scores.Hygiene' : 20})
print(" number of documents in the result =   ",number_of_doc)
# Out:
#  number of documents in the result =    41

# %%
# Display the first document in the results using pprint
results = establishments.find({'scores.Hygiene' :{'$eq': 20}})
pprint(results[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48e966d5369e5b7e8c33'),
#  'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
query = {'scores.Hygiene' :{'$eq': 20}}
results = establishments.find(query)
result_df = pd.DataFrame(results)
print("Rows in DataFrame: ", len(result_df))
# result_df.head(10)
# Out:
# Rows in DataFrame:  41

# %%
# # Display the number of rows in the DataFrame
number_of_rows = len(result_df )
number_of_rows
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
pprint(result_df[0:9])
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65bc48e966d5369e5b7e8c33   110681                  0
# 1  65bc48e966d5369e5b7e8fa3   612039                  0
# 2  65bc48e966d5369e5b7e92a8   730933                  0
# 3  65bc48e966d5369e5b7e9499   172735                  0
# 4  65bc48e966d5369e5b7e94a8   172953                  0
# 5  65bc48ea66d5369e5b7e9e44   512854                  0
# 6  65bc48ea66d5369e5b7ea06a  1537089                  0
# 7  65bc48ea66d5369e5b7eb58f   155648                  0
# 8  65bc48ea66d5369e5b7eb9d6  1012883                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': '0.27694', 'latitude': '50.769705'}
# 1  {'longitude': '1.278721', 'latitude': '51.8575...
# 2  {'longitude': '1.15927', 'latitude': '51.789429'}
# 3  {'longitude': '0.10202', 'latitude': '50.770885'}
# 4  {'longitude': '0.101446', 'latitude': '50.7707...
# 5  {'longitude': '0.736349', 'latitude': '51.5414...
# 6  {'longitude': '0.7121671', 'latitude': '51.535...
# 7  {'longitude': '0.602364', 'latitude': '51.5915...
# 8  {'longitude': '0.146449998021126', 'latitude':...
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [9 rows x 28 columns]

# %% [markdown]
# ## 2. Which establishments in London have a RatingValue greater than or equal to 4?

# %%
# # Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"$and" :[
                {'LocalAuthorityName' :{'$regex' : 'London'}},
                #{'RatingValue':{'$gte' : 4}}
                ]}

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query))

# Display the first document in the results using pprint

results =  establishments.find(query)
pprint(results[0])
# Out:
# Number of documents in result: 37
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48ea66d5369e5b7ea63d'),
#  'geocode': {'latitude': '51.369321', 'longitude': '0.508551'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
query = {'LocalAuthorityName': {'$regex': "London"}}
results = establishments.find(query )
df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(df))

# Display the first 10 rows of the DataFrame
results = establishments.find(query )
for i in range(10):
    pprint(results[i])
# Out:
# Rows in DataFrame:  37
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48ea66d5369e5b7ea63d'),
#  'geocode': {'latitude': '51.369321', 'longitude': '0.508551'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}
# {'AddressLine1': 'Cherry Garden Pier',
#  'AddressLine2': 'Cherry Garden Street Rotherhithe',
#  'AddressLine3': 'Charlton',
#  'AddressLine4': '',
#  'BusinessName': 'Mv City Cruises Erasmus',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.8731788858,
#  'FHRSID': 1130836,
#  'LocalAuthorityBusinessID': 'PI/000034075',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN4 8HR',
#  'RatingDate': '2021-05-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48ea66d5369e5b7ea963'),
#  'geocode': {'latitude': '51.1236228942871', 'longitude': '0.249255999922752'},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1130836',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Ferry Road',
#  'AddressLine2': 'South Benfleet Essex',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Benfleet Motor Yacht Club',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4631.968418191259,
#  'FHRSID': 293783,
#  'LocalAuthorityBusinessID': 'PI/000002614',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS7 1NF',
#  'RatingDate': '2018-11-02T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48ea66d5369e5b7eb4af'),
#  'geocode': {'latitude': '51.543831', 'longitude': '0.561954'},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/293783',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '1 London Gateway',
#  'AddressLine2': 'London Gateway Drive Stanford-Le-Hope',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Gourmet Kitchen',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4634.42812137316,
#  'FHRSID': 1523645,
#  'LocalAuthorityBusinessID': 'PI/000038853',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS17 9DY',
#  'RatingDate': '2022-05-05T00:00:00',
#  'RatingKey': 'fhrs_3_en-gb',
#  'RatingValue': '3',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48ea66d5369e5b7ebac1'),
#  'geocode': {'latitude': '51.5100659', 'longitude': '0.4596371'},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1523645',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 10}}
# {'AddressLine1': 'Leslie Ford House',
#  'AddressLine2': 'Tilbury',
#  'AddressLine3': 'Charlton',
#  'AddressLine4': '',
#  'BusinessName': 'Coombs Catering t/a The Lock and Key',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4636.846754121153,
#  'FHRSID': 1315095,
#  'LocalAuthorityBusinessID': 'PI/000036464',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM18 7EH',
#  'RatingDate': '2020-12-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48ea66d5369e5b7ec2b0'),
#  'geocode': {'latitude': '51.4640655517578', 'longitude': '0.346336990594864'},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1315095',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Tenants Row Tilbury Docks',
#  'AddressLine2': 'Tilbury Essex',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Tilbury Seafarers Centre',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4636.847649796817,
#  'FHRSID': 294474,
#  'LocalAuthorityBusinessID': 'PI/000014647',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM18 7EH',
#  'RatingDate': '2018-11-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48ea66d5369e5b7ec2b3'),
#  'geocode': {'latitude': '51.464078', 'longitude': '0.346325'},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/294474',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Reeds River Cruises LtdKings ReachRiver ThamesSouthwark',
#  'AddressLine2': 'London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Mv Valulla',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4640.460834256174,
#  'FHRSID': 294900,
#  'LocalAuthorityBusinessID': 'PI/000019066',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM15 5QY',
#  'RatingDate': '2016-08-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48ea66d5369e5b7ec9b9'),
#  'geocode': {'latitude': '51.504071', 'longitude': '0.287555'},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/294900',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Tereza Joanne King George V Lock',
#  'AddressLine2': 'Woolwich Manor Way London',
#  'AddressLine3': 'Charlton',
#  'AddressLine4': '',
#  'BusinessName': 'Froottree',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4648.300000043045,
#  'FHRSID': 1252616,
#  'LocalAuthorityBusinessID': 'PI/000035653',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2NJ',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_awaitinginspection_en-gb',
#  'RatingValue': 'AwaitingInspection',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48eb66d5369e5b7eeac2'),
#  'geocode': {'latitude': '51.5011100769043', 'longitude': '0.0693250000476837'},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1252616',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': 'Funcraft UK Ltd King George V Dock Woolwich Manor Way',
#  'AddressLine2': 'London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Tereza Joanne',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4648.301822363946,
#  'FHRSID': 293756,
#  'LocalAuthorityBusinessID': 'PI/000002538',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2NJ',
#  'RatingDate': '2021-07-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48eb66d5369e5b7eeac5'),
#  'geocode': {'latitude': '51.501121', 'longitude': '0.069286'},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/293756',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Air side London City Airport',
#  'AddressLine2': 'London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Brick Lane Brews',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.1734848484375,
#  'FHRSID': 878523,
#  'LocalAuthorityBusinessID': 'PI/000029844',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2PX',
#  'RatingDate': '2019-01-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc48eb66d5369e5b7eee8a'),
#  'geocode': {'latitude': '51.503733', 'longitude': '0.048006'},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/878523',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}}

# %% [markdown]
# ## 3. What are the top 5 establishments with a RatingValue rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?¶

# %%
establishments.update_many({}, [{'$set': {'geocode.longitude': {'$toDouble': "$geocode.longitude"},
                                           'geocode.latitude': {'$toDouble': "$geocode.latitude" }
                                           }}])

# %%
#Get Greenwich coordinate where Penang Flavours located
query = {'LocalAuthorityName': 'Greenwich','RatingValue':{'$eq' : '5'}}
fields = {'geocode','RatingValue'}
results = establishments.find_one(query,fields)
pprint(results)
import pandas as pd
df = pd.DataFrame(results)
df
# Out:
# {'RatingValue': '5',
#  '_id': ObjectId('65bc48ea66d5369e5b7edddc'),
#  'geocode': {'latitude': 51.4320613, 'longitude': 0.0740289}}
#                                 _id RatingValue    geocode
# latitude   65bc48ea66d5369e5b7edddc           5  51.432061
# longitude  65bc48ea66d5369e5b7edddc           5   0.074029

# %%
#Greenwich coordinate where Penang Flavours located taken from the above filter

latitude = 51.4320613
longitude = 0.0740289
degree_search = 0.01


query  = {'geocode.latitude': {'$gte':latitude-degree_search, '$lte':latitude+degree_search}, 
         'geocode.longitude': {'$gte': longitude-degree_search, '$lte': longitude+degree_search},
         'RatingValue': '5'}
sort = [("scores.Hygiene",1)]  
limit = 5
                    
                                                
# Print the results

pprint(list(establishments.find(query).sort(sort).limit(limit)))
# Out:
# [{'AddressLine1': '76 Green Lane',
#   'AddressLine2': 'Chislehurst',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'BusinessName': 'Co-op',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4645.481850652601,
#   'FHRSID': 358652,
#   'LocalAuthorityBusinessID': '11/00111/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BR7 6AZ',
#   'RatingDate': '2018-11-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bc48ea66d5369e5b7edd66'),
#   'geocode': {'latitude': 51.422658, 'longitude': 0.067796},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/358652',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Belmont Lane',
#   'AddressLine2': 'Chislehurst',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'BusinessName': 'Edgebury Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4645.384390188426,
#   'FHRSID': 357582,
#   'LocalAuthorityBusinessID': '00000/0000/8/092',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BR7 6BL',
#   'RatingDate': '2018-10-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bc48ea66d5369e5b7edcfa'),
#   'geocode': {'latitude': 51.423689, 'longitude': 0.071497},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/357582',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '46 Avery Hill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Avery Hill',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Yasaka Sushi',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4645.807295344948,
#   'FHRSID': 1402972,
#   'LocalAuthorityBusinessID': '14686',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 2BJ',
#   'RatingDate': '2021-09-21T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bc48ea66d5369e5b7ede90'),
#   'geocode': {'latitude': 51.4392473, 'longitude': 0.0755201},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1402972',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Sidcup Family Golf',
#   'AddressLine2': 'Sidcup By Pass Road',
#   'AddressLine3': 'Chislehurst',
#   'AddressLine4': '',
#   'BusinessName': 'Mr Mulligans Coffee Shop',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4645.486762099276,
#   'FHRSID': 987767,
#   'LocalAuthorityBusinessID': '17/00080/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BR7 6RP',
#   'RatingDate': '2019-06-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bc48ea66d5369e5b7edd75'),
#   'geocode': {'latitude': 51.4315147399902, 'longitude': 0.0765409991145134},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/987767',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Dulverton School',
#   'AddressLine2': 'Dulverton Road',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Independent Catering Management At Dulverton Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4645.46991106295,
#   'FHRSID': 1402880,
#   'LocalAuthorityBusinessID': '21/00281/CP',
#   'LocalAuthorityCode': '503',
#   'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#   'LocalAuthorityName': 'Bexley',
#   'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 3RH',
#   'RatingDate': '2021-11-17T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bc48ea66d5369e5b7edd5b'),
#   'geocode': {'latitude': 51.4354901, 'longitude': 0.0809898},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1402880',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %%
# Convert result to Pandas DataFrame
query  = {'geocode.latitude': {'$gte':latitude-degree_search, '$lte':latitude+degree_search}, 
         'geocode.longitude': {'$gte': longitude-degree_search, '$lte': longitude+degree_search},
         'RatingValue': '5'}
results = establishments.find(query)
df = pd.DataFrame(results)
df
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   65bc48ea66d5369e5b7edc15   329574                  0
# 1   65bc48ea66d5369e5b7edc5c   329565                  0
# 2   65bc48ea66d5369e5b7edcee   358390                  0
# 3   65bc48ea66d5369e5b7edcfa   357582                  0
# 4   65bc48ea66d5369e5b7edd5b  1402880                  0
# 5   65bc48ea66d5369e5b7edd66   358652                  0
# 6   65bc48ea66d5369e5b7edd75   987767                  0
# 7   65bc48ea66d5369e5b7edddc  1451407                  0
# 8   65bc48ea66d5369e5b7ede86   694530                  0
# 9   65bc48ea66d5369e5b7ede90  1402972                  0
# 10  65bc48ea66d5369e5b7ede95  1471938                  0
# 11  65bc48ea66d5369e5b7ede97   694073                  0
# 12  65bc48ea66d5369e5b7edea3   694078                  0
# 13  65bc48ea66d5369e5b7edea4  1069655                  0
# 14  65bc48ea66d5369e5b7edeb1  1270497                  0
# 15  65bc48ea66d5369e5b7edeb2  1049179                  0
# 16  65bc48ea66d5369e5b7edec6  1494354                  0
# 17  65bc48ea66d5369e5b7edec7   944956                  0
# 18  65bc48ea66d5369e5b7edec8  1494355                  0
# 19  65bc48ea66d5369e5b7edeca  1357498                  0
# 20  65bc48ea66d5369e5b7edecb   706401                  0
# 21  65bc48ea66d5369e5b7edecc   893292                  0
# 22  65bc48ea66d5369e5b7edecd  1212986                  0
# 23  65bc48ea66d5369e5b7eded7   694323                  0
# 24  65bc48ea66d5369e5b7edef5   841436                  0
# 25  65bc48ea66d5369e5b7edefc  1514702                  0
# 26  65bc48ea66d5369e5b7edeff   694322                  0
# 27  65bc48ea66d5369e5b7edf09  1038217                  0
# 28  65bc48ea66d5369e5b7edf13  1268538                  0
# 29  65bc48ea66d5369e5b7edf1a   694733                  0
# 30  65bc48ea66d5369e5b7edf1f   694736                  0
# 31  65bc48ea66d5369e5b7edf2a   694320                  0
# 32  65bc48ea66d5369e5b7edf2e  1151397                  0
# 33  65bc48ea66d5369e5b7edf31  1262107                  0
# 34  65bc48ea66d5369e5b7edf38   694319                  0
# 35  65bc48ea66d5369e5b7edf41   694995                  0
# 36  65bc48ea66d5369e5b7edf4d   695210                  0
# 37  65bc48ea66d5369e5b7edf53  1077918                  0
# 38  65bc48ea66d5369e5b7edf62   695005                  0
# 39  65bc48ea66d5369e5b7edf67  1289142                  0
# 40  65bc48ea66d5369e5b7edf70  1170956                  0
# 41  65bc48ea66d5369e5b7edf74  1255594                  0
# 42  65bc48ea66d5369e5b7edf7d   695211                  0
# 43  65bc48ea66d5369e5b7edf7f   694315                  0
# 44  65bc48ea66d5369e5b7edf80  1341366                  0
# 45  65bc48ea66d5369e5b7edf8a  1193269                  0
# 46  65bc48ea66d5369e5b7edf97   694724                  0
# 47  65bc48ea66d5369e5b7edfaa  1385115                  0
# 48  65bc48ea66d5369e5b7edfab  1439550                  0
#
#    LocalAuthorityBusinessID  \
# 0          15290/0008/4/000
# 1          15270/0327/0/000
# 2            07/00055/MIXED
# 3          00000/0000/8/092
# 4               21/00281/CP
# 5            11/00111/MIXED
# 6            17/00080/MIXED
# 7                     14959
# 8              PI/000104365
# 9                     14686
# 10                    15033
# 11             PI/000007353
# 12             PI/000007452
# 13             PI/000207269
# 14                    13665
# 15             PI/000206160
# 16                    15126
# 17             PI/000172049
# 18                    15127
# 19                    14243
# 20             PI/000195100
# 21             PI/000199812
# 22                    13227
# 23             PI/000058591
# 24             PI/000198598
# 25                    15193
# 26             PI/000058585
# 27             PI/000205670
# 28                    13646
# 29             PI/000136285
# 30             PI/000136326
# 31             PI/000058557
# 32                    12775
# 33                    13569
# 34             PI/000058552
# 35             PI/000171247
# 36             PI/000178059
# 37             PI/000207614
# 38             PI/000171591
# 39                    13848
# 40                    12892
# 41                    13530
# 42             PI/000178068
# 43             PI/000058486
# 44                    14142
# 45                    13034
# 46             PI/000134206
# 47                    14461
# 48                    14948
#
#                                          BusinessName  \
# 0                                          Limoncello
# 1                              St Mary's Nursing Home
# 2                           Blossom Years Day Nursery
# 3                             Edgebury Primary School
# 4   Independent Catering Management At Dulverton P...
# 5                                               Co-op
# 6                            Mr Mulligans Coffee Shop
# 7                                   Oaks Nursing Home
# 8                     Providence Linc United Services
# 9                                        Yasaka Sushi
# 10                                   Freestyle Feasts
# 11                             New Eltham Social Club
# 12                                   NEW ELTHAM GRILL
# 13                                     Mandarin House
# 14                               The Bubble & Sausage
# 15                  New Eltham Fish and Chips - Kebab
# 16                                   Ruchita Tandoori
# 17                                        Laabham Ltd
# 18                                         ISHA SPICE
# 19                                        Pizza lover
# 20                                      Pizza Hot 4 U
# 21                       Cinar Village Market Limited
# 22                                     Lai Loi Street
# 23                  Pope Street Bar & Kitchen Limited
# 24                                   Kebab Ye Express
# 25                                      Churros Libre
# 26                                Premium Off Licence
# 27                                         Munch Cafe
# 28                                 Elsie's Pie N Mash
# 29                   New Eltham Conservative Club Ltd
# 30                     New Eltham Library Coffee Shop
# 31                                         Co-op Food
# 32                                             CAFTAO
# 33                                    Cray's Fish Bar
# 34                                Emerald Food Centre
# 35                                               Nisa
# 36                                        The Beehive
# 37                                New Eltham Butchers
# 38                                       Le Spice Ltd
# 39                                           Blossoms
# 40                      St Olave's Preparatory School
# 41                                        Katsu Shoku
# 42                                     The Alpha Club
# 43                         Tai Pan Chinese Restaurant
# 44                                    Zavi Restaurant
# 45                              Morleys Fried Chicken
'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 36  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 37  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 38  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 39  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 40  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 41  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 42  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 43  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 44  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 45  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 46  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 47  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 48  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                               geocode RightToReply  \
# 0      {'longitude': 0.083451, 'latitude': 51.430663}
# 1      {'longitude': 0.082105, 'latitude': 51.430813}
# 2      {'longitude': 0.075336, 'latitude': 51.427165}
# 3      {'longitude': 0.071497, 'latitude': 51.423689}
# 4    {'longitude': 0.0809898, 'latitude': 51.4354901}
# 5      {'longitude': 0.067796, 'latitude': 51.422658}
# 6   {'longitude': 0.0765409991145134, 'latitude': ...
# 7    {'longitude': 0.0740289, 'latitude': 51.4320613}
# 8    {'longitude': 0.0666571, 'latitude': 51.4300243}
# 9    {'longitude': 0.0755201, 'latitude': 51.4392473}
# 10   {'longitude': 0.0747098, 'latitude': 51.4386363}
# 11   {'longitude': 0.0747098, 'latitude': 51.4386363}
# 12   {'longitude': 0.0756871, 'latitude': 51.4397569}
# 13    {'longitude': 0.0754082, 'latitude': 51.439636}
# 14   {'longitude': 0.0752176, 'latitude': 51.4395584}
# 15   {'longitude': 0.0752624, 'latitude': 51.4395936}
# 16   {'longitude': 0.0737691, 'latitude': 51.4387117}
# 17   {'longitude': 0.0722594, 'latitude': 51.4371467}
# 18   {'longitude': 0.0737691, 'latitude': 51.4387117}
# 19   {'longitude': 0.0737243, 'latitude': 51.4386765}
# 20   {'longitude': 0.0737243, 'latitude': 51.4386765}
# 21   {'longitude': 0.0721456, 'latitude': 51.4371757}
# 22   {'longitude': 0.0736352, 'latitude': 51.4386152}
# 23    {'longitude': 0.0720067, 'latitude': 51.437286}
# 24  {'longitude': 0.0713699981570244, 'latitude': ...
# 25    {'longitude': 0.0743322, 'latitude': 51.440977}
# 26   {'longitude': 0.0715946, 'latitude': 51.4383545}
# 27   {'longitude': 0.0716118, 'latitude': 51.4384171}
# 28   {'longitude': 0.0714318, 'latitude': 51.4385732}
# 29   {'longitude': 0.0684871, 'latitude': 51.4358194}
# 30  {'longitude': 0.0689520016312599, 'latitude': ...
# 31   {'longitude': 0.0707321, 'latitude': 51.4384054}
# 32   {'longitude': 0.0702901, 'latitude': 51.4380718}
# 33   {'longitude': 0.0707705, 'latitude': 51.4385849}
# 34   {'longitude': 0.0709601, 'latitude': 51.4389592}
# 35   {'longitude': 0.0705749, 'latitude': 51.4387142}
# 36     {'longitude': 0.07087, 'latitude': 51.4391946}
# 37    {'longitude': 0.0704113, 'latitude': 51.438915}
# 38    {'longitude': 0.0702908, 'latitude': 51.439115}
# 39    {'longitude': 0.070209, 'latitude': 51.4392153}
# 40   {'longitude': 0.0665119, 'latitude': 51.4357284}
# 41   {'longitude': 0.0650887, 'latitude': 51.4341617}
# 42  {'longitude': 0.0703430026769638, 'latitude': ...
# 43   {'longitude': 0.0701548, 'latitude': 51.4392882}
# 44   {'longitude': 0.0651621, 'latitude': 51.4346067}
# 45   {'longitude': 0.0647967, 'latitude': 51.4347064}
# 46   {'longitude': 0.0644055, 'latitude': 51.4343266}
# 47   {'longitude': 0.0702241, 'latitude': 51.4412402}
# 48   {'longitude': 0.0702241, 'latitude': 51.4412402}
#
#        Distance NewRatingPending  \
# 0   4645.203182            False
# 1   4645.257837            False
# 2   4645.371453            False
# 3   4645.384390            False
# 4   4645.469911            False
# 5   4645.481851            False
# 6   4645.486762            False
# 7   4645.598536            False
# 8   4645.793205            False
# 9   4645.807295            False
# 10  4645.814504            False
# 11  4645.814504            False
# 12  4645.819864            False
# 13  4645.825620            False
# 14  4645.829738            False
# 15  4645.829391            False
# 16  4645.851619            False
# 17  4645.849429            False
# 18  4645.851619            False
# 19  4645.851966            False
# 20  4645.851966            False
# 21  4645.854648            False
# 22  4645.852975            False
# 23  4645.863760            False
# 24  4645.903933            False
# 25  4645.914035            False
# 26  4645.917947            False
# 27  4645.919612            False
# 28  4645.931903            False
# 29  4645.938589            False
# 30  4645.945019            False
# 31  4645.951310            False
# 32  4645.955233            False
# 33  4645.956482            False
# 34  4645.963267            False
# 35  4645.968361            False
# 36  4645.975180            False
# 37  4645.981691            False
# 38  4645.993417            False
# 39  4646.000078            False
# 40  4646.007398            False
# 41  4646.002007            False
# 42  4646.018845            False
# 43  4646.004727            False
# 44  4646.015622            False
# 45  4646.032619            False
# 46  4646.033000            False
# 47  4646.073692            False
# 48  4646.073692            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# 5   {'dataSource': None, 'extractDate': '0001-01-0...
# 6   {'dataSource': None, 'extractDate': '0001-01-0...
# 7   {'dataSource': None, 'extractDate': '0001-01-0...
# 8   {'dataSource': None, 'extractDate': '0001-01-0...
# 9   {'dataSource': None, 'extractDate': '0001-01-0...
# 10  {'dataSource': None, 'extractDate': '0001-01-0...
# 11  {'dataSource': None, 'extractDate': '0001-01-0...
# 12  {'dataSource': None, 'extractDate': '0001-01-0...
# 13  {'dataSource': None, 'extractDate': '0001-01-0...
# 14  {'dataSource': None, 'extractDate': '0001-01-0...
# 15  {'dataSource': None, 'extractDate': '0001-01-0...
# 16  {'dataSource': None, 'extractDate': '0001-01-0...
# 17  {'dataSource': None, 'extractDate': '0001-01-0...
# 18  {'dataSource': None, 'extractDate': '0001-01-0...
# 19  {'dataSource': None, 'extractDate': '0001-01-0...
# 20  {'dataSource': None, 'extractDate': '0001-01-0...
# 21  {'dataSource': None, 'extractDate': '0001-01-0...
# 22  {'dataSource': None, 'extractDate': '0001-01-0...
# 23  {'dataSource': None, 'extractDate': '0001-01-0...
# 24  {'dataSource': None, 'extractDate': '0001-01-0...
# 25  {'dataSource': None, 'extractDate': '0001-01-0...
# 26  {'dataSource': None, 'extractDate': '0001-01-0...
# 27  {'dataSource': None, 'extractDate': '0001-01-0...
# 28  {'dataSource': None, 'extractDate': '0001-01-0...
# 29  {'dataSource': None, 'extractDate': '0001-01-0...
# 30  {'dataSource': None, 'extractDate': '0001-01-0...
# 31  {'dataSource': None, 'extractDate': '0001-01-0...
# 32  {'dataSource': None, 'extractDate': '0001-01-0...
# 33  {'dataSource': None, 'extractDate': '0001-01-0...
# 34  {'dataSource': None, 'extractDate': '0001-01-0...
# 35  {'dataSource': None, 'extractDate': '0001-01-0...
# 36  {'dataSource': None, 'extractDate': '0001-01-0...
# 37  {'dataSource': None, 'extractDate': '0001-01-0...
# 38  {'dataSource': None, 'extractDate': '0001-01-0...
# 39  {'dataSource': None, 'extractDate': '0001-01-0...
# 40  {'dataSource': None, 'extractDate': '0001-01-0...
# 41  {'dataSource': None, 'extractDate': '0001-01-0...
# 42  {'dataSource': None, 'extractDate': '0001-01-0...
# 43  {'dataSource': None, 'extractDate': '0001-01-0...
# 44  {'dataSource': None, 'extractDate': '0001-01-0...
# 45  {'dataSource': None, 'extractDate': '0001-01-0...
# 46  {'dataSource': None, 'extractDate': '0001-01-0...
# 47  {'dataSource': None, 'extractDate': '0001-01-0...
# 48  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links
# 0   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 10  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 11  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 12  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 13  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 14  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 15  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 16  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 17  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 18  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 19  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 20  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 21  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 22  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 23  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 24  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 25  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 26  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 27  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 28  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 29  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 30  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 31  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 32  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 33  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 34  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 35  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 36  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 37  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 38  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 39  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 40  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 41  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 42  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 43  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 44  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 45  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 46  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 47  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 48  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [49 rows x 28 columns]

# %% [markdown]
# ## 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene' :{'$eq': 0}}}
# 2. Groups the matches by Local Authority
group_query = {"$group": {"_id": "$LocalAuthorityName"}}
# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': {'scores.Hygiene': -1}}
# Print the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query))
# pipeline = [match_query, group_query, sort_values]
pipeline = [group_query, match_query,  sort_values]
results = list(establishments.aggregate(pipeline))
# Print the first 10 results
results = establishments.find(query )
pprint(results[0:10])
# Out:
# Number of documents in result: 49
# <pymongo.cursor.Cursor object at 0x000001B04246EC20>

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(df))
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Rows in DataFrame:  10
#                         _id   FHRSID  ChangesByServerID  \
# 0  65bc48ea66d5369e5b7edc15   329574                  0
# 1  65bc48ea66d5369e5b7edc5c   329565                  0
# 2  65bc48ea66d5369e5b7edcee   358390                  0
# 3  65bc48ea66d5369e5b7edcfa   357582                  0
# 4  65bc48ea66d5369e5b7edd5b  1402880                  0
# 5  65bc48ea66d5369e5b7edd66   358652                  0
# 6  65bc48ea66d5369e5b7edd75   987767                  0
# 7  65bc48ea66d5369e5b7edddc  1451407                  0
# 8  65bc48ea66d5369e5b7ede86   694530                  0
# 9  65bc48ea66d5369e5b7ede90  1402972                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0         15290/0008/4/000                                         Limoncello
# 1         15270/0327/0/000                             St Mary's Nursing Home
# 2           07/00055/MIXED                          Blossom Years Day Nursery
# 3         00000/0000/8/092                            Edgebury Primary School
# 4              21/00281/CP  Independent Catering Management At Dulverton P...
# 5           11/00111/MIXED                                              Co-op
# 6           17/00080/MIXED                           Mr Mulligans Coffee Shop
# 7                    14959                                  Oaks Nursing Home
# 8             PI/000104365                    Providence Linc United Services
# 9                    14686                                       Yasaka Sushi
#
#                             BusinessType  BusinessTypeID  \
# 0                Restaurant/Cafe/Canteen               1
# 1                        Caring Premises               5
# 2                        Caring Premises               5
# 3              School/college/university            7845
# 4              School/college/university            7845
# 5  Retailers - supermarkets/hypermarkets            7840
# 6                Restaurant/Cafe/Canteen               1
# 7                        Caring Premises               5
# 8                        Caring Premises               5
# 9                 Takeaway/sandwich shop            7844
#
#                           AddressLine1         AddressLine2 AddressLine3  ...  \
# 0             8-9 Marechal Niel Parade            Main Road       Sidcup  ...
# 1                        327 Main Road               Sidcup         Kent  ...
# 2  Blossom Years Childrens Day Nursery      2C Imperial Way  Chislehurst  ...
# 3                         Belmont Lane          Chislehurst               ...
# 4                     Dulverton School       Dulverton Road       London  ...
# 5                        76 Green Lane          Chislehurst               ...
# 6                   Sidcup Family Golf  Sidcup By Pass Road  Chislehurst  ...
# 7             The Oaks 904 Sidcup Road                            Eltham  ...
# 8                    88 Montbelle Road                            Eltham  ...
# 9                   46 Avery Hill Road                        Avery Hill  ...
#
#               LocalAuthorityWebSite    LocalAuthorityEmailAddress  \
# 0          http://www.bexley.gov.uk     food.safety@bexley.gov.uk
# 1          http://www.bexley.gov.uk     food.safety@bexley.gov.uk
# 2         http://www.bromley.gov.uk           food@bromley.gov.uk
# 3         http://www.bromley.gov.uk           food@bromley.gov.uk
# 4          http://www.bexley.gov.uk     food.safety@bexley.gov.uk
# 5         http://www.bromley.gov.uk           food@bromley.gov.uk
# 6         http://www.bromley.gov.uk           food@bromley.gov.uk
# 7  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 8  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 9  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.083451, 'latitude': 51.430663}
# 1     {'longitude': 0.082105, 'latitude': 51.430813}
# 2     {'longitude': 0.075336, 'latitude': 51.427165}
# 3     {'longitude': 0.071497, 'latitude': 51.423689}
# 4   {'longitude': 0.0809898, 'latitude': 51.4354901}
# 5     {'longitude': 0.067796, 'latitude': 51.422658}
# 6  {'longitude': 0.0765409991145134, 'latitude': ...
# 7   {'longitude': 0.0740289, 'latitude': 51.4320613}
# 8   {'longitude': 0.0666571, 'latitude': 51.4300243}
# 9   {'longitude': 0.0755201, 'latitude': 51.4392473}
#
#       Distance NewRatingPending  \
# 0  4645.203182            False
# 1  4645.257837            False
# 2  4645.371453            False
# 3  4645.384390            False
# 4  4645.469911            False
# 5  4645.481851            False
# 6  4645.486762            False
# 7  4645.598536            False
# 8  4645.793205            False
# 9  4645.807295            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]
